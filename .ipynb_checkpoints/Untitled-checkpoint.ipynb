# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import pandas as pd
import urllib
import os


tabela = pd.read_excel("Envios.xlsx")
display(tabela[['nome', 'mensagem', 'arquivo', 'telefone']])


navegador = webdriver.Firefox()
navegador.get("https://web.whatsapp.com")


while len(navegador.find_elements(By.ID, 'side')) < 1:
    time.sleep(1)
time.sleep(3)


for linha in tabela.index:
    
    nome = tabela.loc[linha, "nome"]
    mensagem = tabela.loc[linha, "mensagem"]
    arquivo = tabela.loc[linha, "arquivo"]
    telefone = tabela.loc[linha, "telefone"]
    
    texto = mensagem.replace("fulano", nome)
    texto = urllib.parse.quote(texto)

    # botão de enviar a mensagem
    link = f"https://web.whatsapp.com/send?phone=+{telefone}&text={texto}"
    
    navegador.get(link)
   
    while len(navegador.find_elements(By.ID, 'side')) < 1: 
        time.sleep(1)
    time.sleep(3) 
    
    tentativas = 3
    while tentativas > 0:
        try:
            if len(navegador.find_elements(By.XPATH, '/html/body/div[1]/div/span[2]/div/span/div/div/div/div/div/div[2]/div/div/div/div')) < 1:
                
                navegador.find_element(By.XPATH, '/html/body/div[1]/div/div/div[5]/div/footer/div[1]/div/span[2]/div/div[2]/div[2]/button').click()
                
                if arquivo != "N":
                    caminho_completo = os.path.abspath(f"arquivos/{arquivo}")
                    navegador.find_element(By.XPATH, 
                                           '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[1]/div[2]/div/div/span').click()
                    navegador.find_element(By.XPATH, 
                                           '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[1]/div[2]/div/span/div/div/ul/li[4]/button/input').send_keys(caminho_completo)
                    time.sleep(2)
                    navegador.find_element(By.XPATH, 
                                           '//*[@id="app"]/div/div/div[2]/div[2]/span/div/span/div/div/div[2]/div/div[2]/div[2]/div/div').click()
                
                time.sleep(3)
                
                tabela = tabela.drop(linha, axis=0)
                tabela.to_excel("Envios.xlsx", index=False)
                break
            else:
                tentativas -= 1
                time.sleep(1)
        except:
            tentativas -= 1
            time.sleep(1)
  
    else:
        continue


navegador.quit()
# Out:
#       nome                                           mensagem arquivo  \
# 0    aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 1    aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 2    aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 3    aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 4    aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# ..     ...                                                ...     ...
# 117  aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 118  aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 119  aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 120  aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
# 121  aluno  📚 HORA DE RENOVAR A SUA MATRÍCULA PARA 2023.2!...       N
#
#          telefone
# 0    83 999690610
# 1    83 987207725
# 2    83 986393362
# 3    83 986412842
# 4    83 988106053
# ..            ...
# 117  83 987478955
# 118  83 991017932
# 119  83 988848425
# 120  83 982072546
# 121  83 987854556
#
# [122 rows x 4 columns]
